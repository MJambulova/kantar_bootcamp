# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas introduce 2 new data types:
# Series AND
# DataFrame

# %% [markdown]
# # Pandas intro

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dictionary = {'A':[1,2,3],'B':['a','b','c']}

# %%
pd.DataFrame(dictionary)
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c

# %% [markdown]
# ## Reading Files, Selecting columns

# %%
pwd
# Out:
# 'C:\\Users\\JambulovaM\\whitehat-datascience\\kantar_bootcamp\\Data Science Bootcamp 2'

# %%
#Load our data 
users = pd.read_csv('data/user.tbl', sep = '|')

# %%
pwd
# Out:
# 'C:\\Users\\JambulovaM\\whitehat-datascience\\kantar_bootcamp\\Data Science Bootcamp 2'

# %%
#Examine our data 
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(users)
# Out:
# pandas.core.frame.DataFrame

# %%
#Print the first five rows from the dataset

users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
list(users.columns)
# Out:
# ['user_id', 'age', 'gender', 'occupation', 'zip_code']

# %%
# Select a column - the below can be used for simple column names

users.age
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
# For column names that have a space use the below code
users['age']
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
#using double brackets we are changing the data type from series to DataFrame
users[['age']]
# Out:
#      age
# 0     24
# 1     53
# 2     23
# 3     24
# 4     33
# ..   ...
# 938   26
# 939   32
# 940   20
# 941   48
# 942   22
#
# [943 rows x 1 columns]

# %%
users[['age','gender']]
# Out:
#      age gender
# 0     24      M
# 1     53      F
# 2     23      M
# 3     24      M
# 4     33      F
# ..   ...    ...
# 938   26      F
# 939   32      M
# 940   20      M
# 941   48      F
# 942   22      M
#
# [943 rows x 2 columns]

# %%
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
#check the shape of our dataset - how many rows and how many columns
users.shape
# Out:
# (943, 5)

# %%
#Summary of dataset

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
# Describe all numeric columns - all integers in the dataframe would be given summary statistics

users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.describe(include=['object'])

#unique - unique values; top - the most frequent value; freq - the number of times that the top value is present
# Out:
#        gender occupation zip_code
# count     943        943      943
# unique      2         21      795
# top         M    student    55414
# freq      670        196        9

# %%
users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
#We can use describe command for specific columns by calling them in the code
users.age.describe()
# Out:
# count    943.000000
# mean      34.051962
# std       12.192740
# min        7.000000
# 25%       25.000000
# 50%       31.000000
# 75%       43.000000
# max       73.000000
# Name: age, dtype: float64

# %%
average_age = users.age.mean()

# %%
average_age
# Out:
# 34.05196182396607

# %%
#using Pandas to call a matplotlib graph
users.age.hist()

# %% [markdown]
# # Counting the number of occurences for each value

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# value_counts is a command for categorical values
users.gender.value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
users.gender.value_counts().plot(kind='bar')

# %%
# Value_counts used on numerical values will show frequency for each integer
users.age.value_counts()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64

# %%
users.age.value_counts().sort_index()
# Out:
# 7     1
# 10    1
# 11    1
# 13    5
# 14    3
#      ..
# 66    1
# 68    2
# 69    2
# 70    3
# 73    1
# Name: age, Length: 61, dtype: int64

# %%
users.age.value_counts().sort_index().plot(kind='bar')

# %%
users.age.value_counts().sort_index().plot(kind='bar',figsize=(12,8))
plt.title('Distribution of ages')
plt.xlabel('Age')
plt.ylabel('Number of users per age')
# Out:
# Text(0, 0.5, 'Number of users per age')

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Read drinks.csv into a Dataframe called drinks

# %%
#Load our data 
drinks = pd.read_csv('data/drinks.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# 1) Print the first and last 5 rows of the data

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# 2) Examine the index, datatypes and shape of the drinks data

list(drinks.columns)
# Out:
# ['country',
#  'beer_servings',
#  'spirit_servings',
#  'wine_servings',
#  'total_litres_of_pure_alcohol',
#  'continent']

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.shape
# Out:
# (193, 6)

# %%
# 3) Print the first 5 rows of the beer_servings column
drinks.beer_servings.head()
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
drinks[['beer_servings']].head()
# Out:
#    beer_servings
# 0              0
# 1             89
# 2             25
# 3            245
# 4            217

# %%
# 4) Calcuate the average beer_servings for the entire dataset
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# 5) Count the number of occurrences of each 'continent' value
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %% [markdown]
# # Section 2: Filtering and Sorting

# %% [markdown]
# Logical Filtering:

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users['age'] < 20
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: age, Length: 943, dtype: bool

# %%
# How to return values that are below 20 - create a variable

under_20 = users['age'] < 20

users[under_20]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M       none    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F   salesman    49036
#
# [77 rows x 5 columns]

# %%
users[users['age'] < 20]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M       none    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F   salesman    49036
#
# [77 rows x 5 columns]

# %%
mask = users.occupation == 'student'

# %%
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938     True
# 939    False
# 940     True
# 941    False
# 942     True
# Name: occupation, Length: 943, dtype: bool

# %%
users[mask]
# Out:
#      user_id  age gender occupation zip_code
# 8          9   29      M    student    01002
# 29        30    7      M    student    55436
# 31        32   28      F    student    78741
# 32        33   23      M    student    27510
# 35        36   19      F    student    93117
# ..       ...  ...    ...        ...      ...
# 927      928   21      M    student    55408
# 932      933   28      M    student    48105
# 938      939   26      F    student    33319
# 940      941   20      M    student    97229
# 942      943   22      M    student    77841
#
# [196 rows x 5 columns]

# %%
# Save mask as a variable
students = users[mask]

# %%
students.head()
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741
# 32       33   23      M    student    27510
# 35       36   19      F    student    93117

# %% [markdown]
# # Logical Filtering with multiple conditions

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# What are the European countries that drink a lot of beer

mask = (drinks.beer_servings > 25) & (drinks.continent == 'EU')

# %%
mask
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
drinks[mask]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# ...

# %%
# What are the countries that drink a lot of beer OR in Europe

mask = (drinks.beer_servings > 25) | (drinks.continent == 'EU')

# %%
drinks[mask]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 185            Uruguay            115               35            220
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# ...

# %%
# What are the countries that drink a lot of beer OR in Europe

mask = ((drinks.beer_servings > 25) & (drinks.continent == 'EU')) | (drinks.wine_servings > 200)

# %%
drinks[mask]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 6             Argentina            193               25            221
# 8             Australia            261               72            212
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
(True and False) or True
# Out:
# True

# %%
users[users.occupation.isin(['student', 'doctor'])]
# Out:
#      user_id  age gender occupation zip_code
# 8          9   29      M    student    01002
# 29        30    7      M    student    55436
# 31        32   28      F    student    78741
# 32        33   23      M    student    27510
# 35        36   19      F    student    93117
# ..       ...  ...    ...        ...      ...
# 932      933   28      M    student    48105
# 934      935   42      M     doctor    66221
# 938      939   26      F    student    33319
# 940      941   20      M    student    97229
# 942      943   22      M    student    77841
#
# [203 rows x 5 columns]

# %% [markdown]
# ## Sorting
