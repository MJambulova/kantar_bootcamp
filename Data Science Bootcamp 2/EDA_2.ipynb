# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drinks = pd.read_csv('data/drinks.csv')

# %% [markdown]
# # Section 3: Renaming, Adding and Removing Columns

# %% [markdown]
# ## Renaming Columns

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
# Rename columns in the drinks dataset 
drinks.rename(columns={'beer_servings':'beer', 'spirit_servings':'spirit', 'wine_servings':'wine'}, inplace=True)

# %%
drinks
# Out:
#          country  beer  spirit  wine  total_litres_of_pure_alcohol continent
# 0    Afghanistan     0       0     0                           0.0        AS
# 1        Albania    89     132    54                           4.9        EU
# 2        Algeria    25       0    14                           0.7        AF
# 3        Andorra   245     138   312                          12.4        EU
# 4         Angola   217      57    45                           5.9        AF
# ..           ...   ...     ...   ...                           ...       ...
# 188    Venezuela   333     100     3                           7.7        SA
# 189      Vietnam   111       2     1                           2.0        AS
# 190        Yemen     6       0     0                           0.1        AS
# 191       Zambia    32      19     4                           2.5        AF
# 192     Zimbabwe    64      18     4                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# 1st method - for renaming specific columns
drinks = drinks.rename(columns={'beer_servings':'beer', 'spirit_servings':'spirit', 'wine_servings':'wine'})

# %%
drinks
# Out:
#          country  beer  spirit  wine  total_litres_of_pure_alcohol continent
# 0    Afghanistan     0       0     0                           0.0        AS
# 1        Albania    89     132    54                           4.9        EU
# 2        Algeria    25       0    14                           0.7        AF
# 3        Andorra   245     138   312                          12.4        EU
# 4         Angola   217      57    45                           5.9        AF
# ..           ...   ...     ...   ...                           ...       ...
# 188    Venezuela   333     100     3                           7.7        SA
# 189      Vietnam   111       2     1                           2.0        AS
# 190        Yemen     6       0     0                           0.1        AS
# 191       Zambia    32      19     4                           2.5        AF
# 192     Zimbabwe    64      18     4                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# 2nd method - define new variable and use it when loading the data
drinks_cols = ['country', 'beer', 'vodka', 'wine', 'litres', 'continent']
drinks = pd.read_csv('data/drinks.csv', header=0, names=drinks_cols)

# %%
drinks
# Out:
#          country  beer  vodka  wine  litres continent
# 0    Afghanistan     0      0     0     0.0        AS
# 1        Albania    89    132    54     4.9        EU
# 2        Algeria    25      0    14     0.7        AF
# 3        Andorra   245    138   312    12.4        EU
# 4         Angola   217     57    45     5.9        AF
# ..           ...   ...    ...   ...     ...       ...
# 188    Venezuela   333    100     3     7.7        SA
# 189      Vietnam   111      2     1     2.0        AS
# 190        Yemen     6      0     0     0.1        AS
# 191       Zambia    32     19     4     2.5        AF
# 192     Zimbabwe    64     18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.columns
# Out:
# Index(['country', 'too_much_beer', 'vodka', 'red_wine', 'gallons',
#        'continent'],
#       dtype='object')

# %%
# 3rd method - with this method you have to mention all columns
drinks_columns = ['country', 'beer', 'spirit', 'wine', 'litres', 'continent']

# %%
drinks
# Out:
#          country  beer  vodka  wine  litres continent
# 0    Afghanistan     0      0     0     0.0        AS
# 1        Albania    89    132    54     4.9        EU
# 2        Algeria    25      0    14     0.7        AF
# 3        Andorra   245    138   312    12.4        EU
# 4         Angola   217     57    45     5.9        AF
# ..           ...   ...    ...   ...     ...       ...
# 188    Venezuela   333    100     3     7.7        SA
# 189      Vietnam   111      2     1     2.0        AS
# 190        Yemen     6      0     0     0.1        AS
# 191       Zambia    32     19     4     2.5        AF
# 192     Zimbabwe    64     18     4     4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# # Adding Columns

# %%
# adding a new column called 'some_column' with a value 'new_value' in every row
drinks['some_column'] = 'new_value'

# %%
drinks
# Out:
#          country  too_much_beer  vodka  red_wine  gallons continent  \
# 0    Afghanistan              0      0         0      0.0        AS
# 1        Albania             89    132        54      4.9        EU
# 2        Algeria             25      0        14      0.7        AF
# 3        Andorra            245    138       312     12.4        EU
# 4         Angola            217     57        45      5.9        AF
# ..           ...            ...    ...       ...      ...       ...
# 188    Venezuela            333    100         3      7.7        SA
# 189      Vietnam            111      2         1      2.0        AS
# 190        Yemen              6      0         0      0.1        AS
# 191       Zambia             32     19         4      2.5        AF
# 192     Zimbabwe             64     18         4      4.7        AF
#
#     some_column
# 0     new_value
# 1     new_value
# 2     new_value
# 3     new_value
# 4     new_value
# ..          ...
# 188   new_value
# ...

# %%
drinks['servings'] = drinks.too_much_beer + drinks.vodka + drinks.red_wine

# %%
drinks
# Out:
#          country  too_much_beer  vodka  red_wine  gallons continent  \
# 0    Afghanistan              0      0         0      0.0        AS
# 1        Albania             89    132        54      4.9        EU
# 2        Algeria             25      0        14      0.7        AF
# 3        Andorra            245    138       312     12.4        EU
# 4         Angola            217     57        45      5.9        AF
# ..           ...            ...    ...       ...      ...       ...
# 188    Venezuela            333    100         3      7.7        SA
# 189      Vietnam            111      2         1      2.0        AS
# 190        Yemen              6      0         0      0.1        AS
# 191       Zambia             32     19         4      2.5        AF
# 192     Zimbabwe             64     18         4      4.7        AF
#
#     some_column  servings
# 0     new_value         0
# 1     new_value       275
# 2     new_value        39
# 3     new_value       695
# ...

# %%
drinks['ml'] = drinks.gallons *1000

# %%
drinks
# Out:
#          country  too_much_beer  vodka  red_wine  gallons continent  \
# 0    Afghanistan              0      0         0      0.0        AS
# 1        Albania             89    132        54      4.9        EU
# 2        Algeria             25      0        14      0.7        AF
# 3        Andorra            245    138       312     12.4        EU
# 4         Angola            217     57        45      5.9        AF
# ..           ...            ...    ...       ...      ...       ...
# 188    Venezuela            333    100         3      7.7        SA
# 189      Vietnam            111      2         1      2.0        AS
# 190        Yemen              6      0         0      0.1        AS
# 191       Zambia             32     19         4      2.5        AF
# 192     Zimbabwe             64     18         4      4.7        AF
#
#     some_column  servings       ml
# 0     new_value         0      0.0
# 1     new_value       275   4900.0
# 2     new_value        39    700.0
# ...

# %% [markdown]
# # Removing Columns

# %%
drinks['some_column'] = 'new_values'

# %%
# Use axis=1 for deleting columns drinks.drop(3, axis=0) for deleting third row
drinks.drop(['some_column'], axis=1, inplace=True)
drinks
# Out:
#          country  beer  vodka  wine  litres continent
# 0    Afghanistan     0      0     0     0.0        AS
# 1        Albania    89    132    54     4.9        EU
# 2        Algeria    25      0    14     0.7        AF
# 3        Andorra   245    138   312    12.4        EU
# 4         Angola   217     57    45     5.9        AF
# ..           ...   ...    ...   ...     ...       ...
# 188    Venezuela   333    100     3     7.7        SA
# 189      Vietnam   111      2     1     2.0        AS
# 190        Yemen     6      0     0     0.1        AS
# 191       Zambia    32     19     4     2.5        AF
# 192     Zimbabwe    64     18     4     4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# # Section 4: Handling Missing Values

# %%
# using the below doesn't count null values
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# Use dropna=False command for the value_counts to count Null values
drinks.continent.value_counts(dropna=False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
# Look at the sum of Null values for column 'continent' using isnull() command
drinks.continent.isnull().sum()
# Out:
# 23

# %%
# Look at the sum of Null values for column 'continent' using notnull() command
drinks.continent.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# Name: continent, Length: 193, dtype: bool

# %%
# Filter out Null values using mask
mask = drinks.continent.notnull()
drinks[mask]
# Out:
#          country  beer  vodka  wine  litres continent
# 0    Afghanistan     0      0     0     0.0        AS
# 1        Albania    89    132    54     4.9        EU
# 2        Algeria    25      0    14     0.7        AF
# 3        Andorra   245    138   312    12.4        EU
# 4         Angola   217     57    45     5.9        AF
# ..           ...   ...    ...   ...     ...       ...
# 188    Venezuela   333    100     3     7.7        SA
# 189      Vietnam   111      2     1     2.0        AS
# 190        Yemen     6      0     0     0.1        AS
# 191       Zambia    32     19     4     2.5        AF
# 192     Zimbabwe    64     18     4     4.7        AF
#
# [170 rows x 6 columns]

# %%
# explore rows in the dataframe
drinks.sum(axis=0)
# Out:
# country    AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# beer                                                   20489
# vodka                                                  15632
# wine                                                    9544
# litres                                                 910.4
# dtype: object

# %%
# explore columns in the dataframe - adding columns for each row
drinks.sum(axis=1)
# Out:
# 0        0.0
# 1      279.9
# 2       39.7
# 3      707.4
# 4      324.9
#        ...
# 188    443.7
# 189    116.0
# 190      6.1
# 191     57.5
# 192     90.7
# Length: 193, dtype: float64

# %%
drinks['wine_litres'] = drinks[['wine', 'litres']].sum(axis=1)
drinks.wine_litres
# Out:
# 0        0.0
# 1       58.9
# 2       14.7
# 3      324.4
# 4       50.9
#        ...
# 188     10.7
# 189      3.0
# 190      0.1
# 191      6.5
# 192      8.7
# Name: wine_litres, Length: 193, dtype: float64

# %%
drinks.columns
# Out:
# Index(['country', 'beer', 'vodka', 'wine', 'litres', 'continent'], dtype='object')

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    193 non-null    object
#  1   beer       193 non-null    int64
#  2   vodka      193 non-null    int64
#  3   wine       193 non-null    int64
#  4   litres     193 non-null    float64
#  5   continent  170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.isnull().sum().plot(kind='bar')

# %%
# drop any row that has Null in every column
drinks.dropna()
# Out:
#          country  beer  vodka  wine  litres continent  wine_litres
# 0    Afghanistan     0      0     0     0.0        AS          0.0
# 1        Albania    89    132    54     4.9        EU         58.9
# 2        Algeria    25      0    14     0.7        AF         14.7
# 3        Andorra   245    138   312    12.4        EU        324.4
# 4         Angola   217     57    45     5.9        AF         50.9
# ..           ...   ...    ...   ...     ...       ...          ...
# 188    Venezuela   333    100     3     7.7        SA         10.7
# 189      Vietnam   111      2     1     2.0        AS          3.0
# 190        Yemen     6      0     0     0.1        AS          0.1
# 191       Zambia    32     19     4     2.5        AF          6.5
# 192     Zimbabwe    64     18     4     4.7        AF          8.7
#
# [170 rows x 7 columns]

# %%
# drop
drinks.dropna(how='all')
# Out:
#          country  beer  vodka  wine  litres continent  wine_litres
# 0    Afghanistan     0      0     0     0.0        AS          0.0
# 1        Albania    89    132    54     4.9        EU         58.9
# 2        Algeria    25      0    14     0.7        AF         14.7
# 3        Andorra   245    138   312    12.4        EU        324.4
# 4         Angola   217     57    45     5.9        AF         50.9
# ..           ...   ...    ...   ...     ...       ...          ...
# 188    Venezuela   333    100     3     7.7        SA         10.7
# 189      Vietnam   111      2     1     2.0        AS          3.0
# 190        Yemen     6      0     0     0.1        AS          0.1
# 191       Zambia    32     19     4     2.5        AF          6.5
# 192     Zimbabwe    64     18     4     4.7        AF          8.7
#
# [193 rows x 7 columns]

# %%
drinks.dropna(inplace = True)

# %%
drinks
# Out:
#          country  beer  vodka  wine  litres continent  wine_litres
# 0    Afghanistan     0      0     0     0.0        AS          0.0
# 1        Albania    89    132    54     4.9        EU         58.9
# 2        Algeria    25      0    14     0.7        AF         14.7
# 3        Andorra   245    138   312    12.4        EU        324.4
# 4         Angola   217     57    45     5.9        AF         50.9
# ..           ...   ...    ...   ...     ...       ...          ...
# 188    Venezuela   333    100     3     7.7        SA         10.7
# 189      Vietnam   111      2     1     2.0        AS          3.0
# 190        Yemen     6      0     0     0.1        AS          0.1
# 191       Zambia    32     19     4     2.5        AF          6.5
# 192     Zimbabwe    64     18     4     4.7        AF          8.7
#
# [170 rows x 7 columns]

# %%
drinks.reset_index()
# Out:
#      index      country  beer  vodka  wine  litres continent  wine_litres
# 0        0  Afghanistan     0      0     0     0.0        AS          0.0
# 1        1      Albania    89    132    54     4.9        EU         58.9
# 2        2      Algeria    25      0    14     0.7        AF         14.7
# 3        3      Andorra   245    138   312    12.4        EU        324.4
# 4        4       Angola   217     57    45     5.9        AF         50.9
# ..     ...          ...   ...    ...   ...     ...       ...          ...
# 165    188    Venezuela   333    100     3     7.7        SA         10.7
# 166    189      Vietnam   111      2     1     2.0        AS          3.0
# 167    190        Yemen     6      0     0     0.1        AS          0.1
# 168    191       Zambia    32     19     4     2.5        AF          6.5
# 169    192     Zimbabwe    64     18     4     4.7        AF          8.7
#
# [170 rows x 8 columns]

# %%
drinks.continent.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
#replace Null with NA

drinks.continent.fillna(value='NA', inplace=True)

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    193 non-null    object
#  1   beer       193 non-null    int64
#  2   vodka      193 non-null    int64
#  3   wine       193 non-null    int64
#  4   litres     193 non-null    float64
#  5   continent  193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# # Exercise

# %%
# %cd
# Out:
# C:\Users\JambulovaM

# %%
pwd
# Out:
# 'C:\\Users\\JambulovaM'

# %%
ufo = pd.read_csv('data/ufo.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-d9aeb070f9ae> in <module>
# ----> 1 ufo = pd.read_csv('data/ufo.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
# %cd ..
# Out:
# C:\Users

# %%
# %cd JambulovaM\whitehat-datascience\kantar_bootcamp\Data Science Bootcamp 2
# Out:
# [WinError 3] The system cannot find the path specified: 'JambulovaM\\whitehat-datascience\\kantar_bootcamp\\Data Science Bootcamp 2'
# C:\Users\JambulovaM

# %%
# %cd
# Out:
# C:\Users\JambulovaM

# %%
# %cd JambulovaM\whitehat-datascience\kantar_bootcamp\Data Science Bootcamp 2
# Out:
# [WinError 3] The system cannot find the path specified: 'JambulovaM\\whitehat-datascience\\kantar_bootcamp\\Data Science Bootcamp 2'
# C:\Users\JambulovaM

# %%
# %cd
# Out:
# C:\Users\JambulovaM

# %%
# %cd whitehat-datascience\kantar_bootcamp\Data Science Bootcamp 2
# Out:
# C:\Users\JambulovaM\whitehat-datascience\kantar_bootcamp\Data Science Bootcamp 2

# %%
ufo = pd.read_csv('data/ufo.csv')

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80543 entries, 0 to 80542
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             80496 non-null  object
#  1   Colors Reported  17034 non-null  object
#  2   Shape Reported   72141 non-null  object
#  3   State            80543 non-null  object
#  4   Time             80543 non-null  object
# dtypes: object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# ## 1) Check the shape of the DataFrame

# %%
ufo.shape
# Out:
# (80543, 5)

# %% [markdown]
# ## 2) What are the three most common colors reported?

# %%
ufo['Colors Reported'].value_counts().head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Colors Reported'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-6408b3362668> in <module>
# ...

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo = ufo.rename(columns={'Colors Reported':'Color','Shape Reported':'Shape'})

# %%
ufo
# Out:
#                        City    colors     shape State             Time
# 0                    Ithaca       NaN  TRIANGLE    NY   6/1/1930 22:00
# 1               Willingboro       NaN     OTHER    NJ  6/30/1930 20:00
# 2                   Holyoke       NaN      OVAL    CO  2/15/1931 14:00
# 3                   Abilene       NaN      DISK    KS   6/1/1931 13:00
# 4      New York Worlds Fair       NaN     LIGHT    NY  4/18/1933 19:00
# ...                     ...       ...       ...   ...              ...
# 80538                Neligh       NaN    CIRCLE    NE   9/4/2014 23:20
# 80539          Uhrichsville       NaN     LIGHT    OH    9/5/2014 1:14
# 80540                Tucson  RED BLUE       NaN    AZ    9/5/2014 2:40
# 80541           Orland park       RED     LIGHT    IL    9/5/2014 3:43
# 80542              Loughman       NaN     LIGHT    FL    9/5/2014 5:30
#
# [80543 rows x 5 columns]

# %%
ufo.colors.value_counts()
# Out:
# ORANGE                          5216
# RED                             4809
# GREEN                           1897
# BLUE                            1855
# YELLOW                           842
# RED ORANGE                       486
# RED GREEN                        469
# RED BLUE                         445
# RED GREEN BLUE                   166
# GREEN BLUE                       147
# RED YELLOW                       146
# ORANGE YELLOW                    137
# ORANGE GREEN                      66
# ORANGE BLUE                       58
# YELLOW GREEN                      53
# RED YELLOW BLUE                   36
# RED YELLOW GREEN                  35
# RED ORANGE YELLOW                 32
# YELLOW BLUE                       27
# RED YELLOW GREEN BLUE             26
# RED ORANGE BLUE                   21
# ORANGE GREEN BLUE                 13
# YELLOW GREEN BLUE                 13
# RED ORANGE GREEN                  12
# RED ORANGE GREEN BLUE              8
# ...

# %% [markdown]
# ## 3) Rename any columns with spaces so that they don't contain spaces.

# %%
ufo = ufo.rename(columns={'Colors Reported':'colors','Shape Reported':'shape', })
ufo
# Out:
#                        City    colors     shape State             Time
# 0                    Ithaca       NaN  TRIANGLE    NY   6/1/1930 22:00
# 1               Willingboro       NaN     OTHER    NJ  6/30/1930 20:00
# 2                   Holyoke       NaN      OVAL    CO  2/15/1931 14:00
# 3                   Abilene       NaN      DISK    KS   6/1/1931 13:00
# 4      New York Worlds Fair       NaN     LIGHT    NY  4/18/1933 19:00
# ...                     ...       ...       ...   ...              ...
# 80538                Neligh       NaN    CIRCLE    NE   9/4/2014 23:20
# 80539          Uhrichsville       NaN     LIGHT    OH    9/5/2014 1:14
# 80540                Tucson  RED BLUE       NaN    AZ    9/5/2014 2:40
# 80541           Orland park       RED     LIGHT    IL    9/5/2014 3:43
# 80542              Loughman       NaN     LIGHT    FL    9/5/2014 5:30
#
# [80543 rows x 5 columns]

# %% [markdown]
# ## 4) For reports in VA, what's the most common city?

# %%
mask = (ufo.State == 'VA')
ufo[mask].City.value_counts().head(1)
# Out:
# Virginia Beach    110
# Name: City, dtype: int64

# %% [markdown]
# ## 5) Print a DataFrame containing only reports from Arlington, VA.

# %%
mask = ((ufo.State == 'VA') & (ufo.City == 'Arlington'))
ufo[mask]
# Out:
#             City      colors      shape State              Time
# 202    Arlington       GREEN       OVAL    VA   7/13/1952 21:00
# 6300   Arlington         NaN    CHEVRON    VA    5/5/1990 21:40
# 10278  Arlington         NaN       DISK    VA   5/27/1997 15:30
# 14527  Arlington         NaN      OTHER    VA   9/10/1999 21:41
# 17984  Arlington         RED       DISK    VA  11/19/2000 22:00
# 21201  Arlington       GREEN   FIREBALL    VA    1/7/2002 17:45
# 22633  Arlington         NaN      LIGHT    VA    7/26/2002 1:15
# 22780  Arlington         NaN      LIGHT    VA    8/7/2002 21:00
# 25066  Arlington         NaN      CIGAR    VA    6/1/2003 22:34
# 27398  Arlington         NaN    VARIOUS    VA   12/13/2003 2:00
# 30608  Arlington         NaN     CIRCLE    VA   10/9/2004 22:30
# 31316  Arlington         NaN  FORMATION    VA   12/13/2004 0:30
# 35787  Arlington         NaN      LIGHT    VA   3/15/2006 22:30
# 37036  Arlington         NaN   TRIANGLE    VA    8/1/2006 22:00
# ...

# %% [markdown]
# ## 6) Count the number of missing values in each column.

# %%
ufo.isnull().sum()
# Out:
# City         47
# colors    63509
# shape      8402
# State         0
# Time          0
# dtype: int64

# %% [markdown]
# ufo.isna().sum()

# %% [markdown]
# ## 7) How many rows remain if you drop all rows with any missing values?

# %%
# dropna will drop any rows that have at least one column with a null/ missing value
ufo.dropna()
# Out:
#                  City colors      shape State             Time
# 12             Belton    RED     SPHERE    SC  6/30/1939 20:00
# 19         Bering Sea    RED      OTHER    AK  4/30/1943 23:00
# 36         Portsmouth    RED  FORMATION    VA   7/10/1945 1:30
# 44          Blairsden  GREEN     SPHERE    CA  6/30/1946 19:00
# 82           San Jose   BLUE    CHEVRON    CA  7/15/1947 21:00
# ...               ...    ...        ...   ...              ...
# 80524         Olympia    RED      LIGHT    WA   9/4/2014 21:10
# 80525       Iowa City   BLUE      LIGHT    IA   9/4/2014 21:11
# 80528  North Royalton    RED   TRIANGLE    OH   9/4/2014 21:30
# 80536         Wyoming    RED       DISK    PA   9/4/2014 23:00
# 80541     Orland park    RED      LIGHT    IL    9/5/2014 3:43
#
# [15510 rows x 5 columns]

# %% [markdown]
# # Split - Apply - Combine

# %%
# Split method - group data by a specific Value
# Apply method - for each group apply 
# Combine method - combine the Split and Apply methods

# %%
drinks = pd.read_csv('Data/drinks.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# get average of beer_servings for each continent 

drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# for each continent calculate the average of every column
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# for beer_servings get a descriptive stats for each continent
drinks.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
# for beer_servings get an agreegate descriptive stats for each continent -  Agg allows us to aggregate results of a series function
drinks.groupby('continent').beer_servings.agg(['mean','count','min','max'])
# Out:
#                  mean  count  min  max
# continent
# AF          61.471698     53    0  376
# AS          37.045455     44    0  247
# EU         193.777778     45    0  361
# OC          89.687500     16    0  306
# SA         175.083333     12   93  333

# %%
# Sort dataframe by Mean
drinks.groupby('continent').beer_servings.agg(['mean','count','min','max']).sort_values('mean')
# Out:
#                  mean  count  min  max
# continent
# AS          37.045455     44    0  247
# AF          61.471698     53    0  376
# OC          89.687500     16    0  306
# SA         175.083333     12   93  333
# EU         193.777778     45    0  361

# %%
# Sort dataframe by Mean in the descending order
drinks.groupby('continent').beer_servings.agg(['mean','count','min','max']).sort_values('mean', ascending = False)
# Out:
#                  mean  count  min  max
# continent
# EU         193.777778     45    0  361
# SA         175.083333     12   93  333
# OC          89.687500     16    0  306
# AF          61.471698     53    0  376
# AS          37.045455     44    0  247

# %%
# counting number of rows for every 'continent' column
drinks.groupby('continent').continent.count()
# Out:
# continent
# AF    53
# AS    44
# EU    45
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# the command above is the same as using value_counts()
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %% [markdown]
# # Exercise 4

# %%
users = pd.read_csv('data/user.tbl', sep= '|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# ### 1) For each occupation in 'users', count the number of occurences

# %%
# Method 1
users.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# salesman          12
# lawyer            12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
# Method 2
users.groupby('occupation').occupation.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: occupation, dtype: int64

# %% [markdown]
# ### 2) For each occupation, calculate the mean age.

# %%
users.groupby('occupation').mean()
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %% [markdown]
# ### 3) For each occupation, calculate the minimum and maximum ages.

# %%
users.groupby('occupation').occupation.agg(['min', 'max'])
# Out:
#                          min            max
# occupation
# administrator  administrator  administrator
# artist                artist         artist
# doctor                doctor         doctor
# educator            educator       educator
# engineer            engineer       engineer
# entertainment  entertainment  entertainment
# executive          executive      executive
# healthcare        healthcare     healthcare
# homemaker          homemaker      homemaker
# lawyer                lawyer         lawyer
# librarian          librarian      librarian
# marketing          marketing      marketing
# none                    none           none
# other                  other          other
# programmer        programmer     programmer
# retired              retired        retired
# salesman            salesman       salesman
# scientist          scientist      scientist
# student              student        student
# technician        technician     technician
# ...

# %% [markdown]
# ### 4) For each combination of occupation and gender, calculate the mean age.

# %%
users.groupby(['occupation','gender']).age.agg('mean')
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...
